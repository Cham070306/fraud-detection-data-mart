# %% [markdown]
# # Notebook đã được hợp nhất
#
# Nội dung data understanding và profiling chính thức nằm trong `01_data_profiling.ipynb`. File này được giữ lại để tương thích với cấu trúc repository ban đầu.
