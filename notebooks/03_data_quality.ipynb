# %% [markdown]
# # Data Quality
#
# Kiểm tra chất lượng dữ liệu có thể tái lập nằm trong `src/etl/validate.py`, `src/etl/reconciliation.py`, `tests/test_data_quality.py` và `tests/test_etl_reconciliation.py`. File này được giữ lại để tương thích với cấu trúc repository ban đầu.
